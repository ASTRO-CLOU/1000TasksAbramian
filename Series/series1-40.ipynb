# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')

# %% [markdown]
# Series1

# %%
try:
    N = 10
    suma = 0
    for i in range(N + 1):
        a = float(input("Введите вещественное число: "))
        suma += a
    print(f"Сумма: {suma}")
except Exception as e:
    print(f"ОШИБКА!: {e}")

# %% [markdown]
# Series2

# %%
try:
    N = 10
    prod = 1.0
    for i in range(N):
        a = float(input("Введите вещественное число: "))
        prod *= a
    print(f"Произведение: {prod}")
except Exception as e:
    print(f"ОШИБКА!: {e}")

# %% [markdown]
# Series3

# %%
try:
    N = 10
    suma = 0.0
    for i in range(N):
        a = float(input("Введите вещественное число: "))
        suma += a
    avg = suma / N
    print(f"Среднее арифметическое: {avg}")
except Exception as e:
    print(f"ОШИБКА!: {e}")

# %% [markdown]
# Series4

# %%
try:
    N = int(input("Введите целое число N: "))
    suma = 0.0
    prod = 1.0
    for i in range(N):
        a = float(input("Введите вещественное число: "))
        suma += a
        prod *= a
    print(f"Сумма: {suma}")
    print(f"Произведение: {prod}")
except Exception as e:
    print(f"ОШИБКА!: {e}")

# %% [markdown]
# Series5

# %%
try:
    N = int(input("Введите целое число N: "))
    suma = 0.0
    for i in range(N):
        a = float(input("Введите положительное вещественное число: "))
        int_part = float(int(a))
        print(f"Целая часть: {int_part}")
        suma += int_part
    print(f"Сумма целых частей: {suma}")
except Exception as e:
    print(f"ОШИБКА!: {e}")

# %% [markdown]
# Series6

# %%
try:
    N = int(input("Введите целое число N: "))
    prod = 1.0
    for i in range(N):
        a = float(input("Введите положительное вещественное число: "))
        frac_part = a - int(a)
        print(f"Дробная часть: {frac_part}")
        prod *= frac_part
    print(f"Произведение дробных частей: {prod}")
except Exception as e:
    print(f"ОШИБКА!: {e}")

# %% [markdown]
# Series7

# %%
try:
    N = int(input("Введите целое число N: "))
    suma = 0
    for i in range(N):
        a = float(input("Введите вещественное число: "))
        rounded = round(a)
        print(f"Округленное значение: {rounded}")
        suma += rounded
    print(f"Сумма округленных значений: {suma}")
except Exception as e:
    print(f"ОШИБКА!: {e}")

# %% [markdown]
# Series8

# %%
try:
    N = int(input("Введите целое число N: "))
    k = 0
    for i in range(N):
        a = int(input("Введите целое число: "))
        if a % 2 == 0:
            print(f"Четное число: {a}")
            k += 1
    print(f"Количество четных K: {k}")
except Exception as e:
    print(f"ОШИБКА!: {e}")

# %% [markdown]
# Series9

# %%
try:
    N = int(input("Введите целое число N: "))
    k = 0
    for i in range(1, N + 1):
        a = int(input("Введите целое число: "))
        if a % 2 != 0:
            print(f"Номер нечетного числа: {i}")
            k += 1
    print(f"Количество нечетных K: {k}")
except Exception as e:
    print(f"ОШИБКА!: {e}")

# %% [markdown]
# Series10

# %%
try:
    N = int(input("Введите целое число N: "))
    has_positive = False
    for i in range(N):
        a = int(input("Введите целое число: "))
        if a > 0:
            has_positive = True
    print(True if has_positive else False)
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_58/2994249119.py in <cell line: 0>()
#       1 try:
# ----> 2     N = int(input("Введите целое число N: "))
#       3     has_positive = False
#       4     for i in range(N):
#       5         a = int(input("Введите целое число: "))
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %% [markdown]
# Series11

# %%
try:
    K = int(input("Введите целое число K: "))
    N = int(input("Введите целое число N: "))
    has_less = False
    for i in range(N):
        a = int(input("Введите целое число: "))
        if a < K:
            has_less = True
    print(True if has_less else False)
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите целое число K:  10
# Введите целое число N:  2
# Введите целое число:  3
# Введите целое число:  15
# True

# %% [markdown]
# Series12

# %%
try:
    count = 0
    while True:
        a = int(input("Введите целое число (0 для завершения): "))
        if a == 0:
            break
        count += 1
    print(f"Количество чисел: {count}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите целое число (0 для завершения):  f
# ОШИБКА!: invalid literal for int() with base 10: 'f'

# %% [markdown]
# Series13

# %%
try:
    suma = 0
    while True:
        a = int(input("Введите целое число (0 для завершения): "))
        if a == 0:
            break
        if a > 0 and a % 2 == 0:
            suma += a
    print(f"Сумма положительных четных: {suma}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите целое число (0 для завершения):  `
# ОШИБКА!: invalid literal for int() with base 10: '`'

# %% [markdown]
# Series14

# %%
try:
    K = int(input("Введите целое число K: "))
    count = 0
    while True:
        a = int(input("Введите целое число (0 для завершения): "))
        if a == 0:
            break
        if a < K:
            count += 1
    print(f"Количество чисел меньше K: {count}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите целое число K:  3
# Введите целое число (0 для завершения):  10
# Введите целое число (0 для завершения):  0
# Количество чисел меньше K: 0

# %% [markdown]
# Series15

# %%
try:
    K = int(input("Введите целое число K: "))
    idx = 0
    first_idx = 0
    while True:
        a = int(input("Введите целое число (0 для завершения): "))
        if a == 0:
            break
        idx += 1
        if a > K and first_idx == 0:
            first_idx = idx
    print(f"Номер первого числа больше K: {first_idx}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите целое число K:  2
# Введите целое число (0 для завершения):  1
# Введите целое число (0 для завершения):  5
# Введите целое число (0 для завершения):  0
# Номер первого числа больше K: 2

# %% [markdown]
# Series16

# %%
try:
    K = int(input("Введите целое число K: "))
    idx = 0
    last_idx = 0
    while True:
        a = int(input("Введите целое число (0 для завершения): "))
        if a == 0:
            break
        idx += 1
        if a > K:
            last_idx = idx
    print(f"Номер последнего числа больше K: {last_idx}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите целое число K:  2
# Введите целое число (0 для завершения):  1
# Введите целое число (0 для завершения):  3
# Введите целое число (0 для завершения):  5
# Введите целое число (0 для завершения):  0
# Номер последнего числа больше K: 3

# %% [markdown]
# Series17

# %%
try:
    B = float(input("Введите вещественное число B: "))
    N = int(input("Введите целое число N: "))
    inserted = False
    for i in range(N):
        a = float(input("Введите элемент набора: "))
        if not inserted and B <= a:
            print(B)
            inserted = True
        print(a)
    if not inserted:
        print(B)
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите вещественное число B:  2.3
# Введите целое число N:  4
# Введите элемент набора:  2
# 2.0
# Введите элемент набора:  5
# 2.3
# 5.0
# Введите элемент набора:  6
# 6.0
# Введите элемент набора:  5
# 5.0

# %% [markdown]
# Series18

# %%
try:
    N = int(input("Введите целое число N: "))
    prev = None
    for i in range(N):
        curr = int(input("Введите элемент набора: "))
        if curr != prev:
            print(f"Различный элемент: {curr}")
            prev = curr
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите целое число N:  2
# Введите элемент набора:  1
# Различный элемент: 1
# Введите элемент набора:  2
# Различный элемент: 2

# %% [markdown]
# Series19

# %%
try:
    N = int(input("Введите целое число N (> 1): "))
    prev = int(input("Введите 1-й элемент: "))
    k = 0
    for i in range(2, N + 1):
        curr = int(input(f"Введите {i}-й элемент: "))
        if curr < prev:
            print(f"Элемент меньше левого соседа: {curr}")
            k += 1
        prev = curr
    print(f"Количество таких элементов (K): {k}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите целое число N (> 1):  3
# Введите 1-й элемент:  1
# Введите 2-й элемент:  4
# Введите 3-й элемент:  `
# ОШИБКА!: invalid literal for int() with base 10: '`'

# %% [markdown]
# Series20

# %%
try:
    N = int(input("Введите целое число N (> 1): "))
    arr = []
    for i in range(N):
        arr.append(int(input(f"Введите {i + 1}-й элемент: ")))
    k = 0
    for i in range(N - 1):
        if arr[i] < arr[i + 1]:
            print(f"Элемент меньше правого соседа: {arr[i]}")
            k += 1
    print(f"Количество таких элементов (K): {k}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите целое число N (> 1):  2
# Введите 1-й элемент:  1
# Введите 2-й элемент:  3
# Элемент меньше правого соседа: 1
# Количество таких элементов (K): 1

# %% [markdown]
# Series21

# %%
try:
    N = int(input("Введите целое число N (> 1): "))
    prev = float(input("Введите 1-й элемент: "))
    is_increasing = True
    for i in range(2, N + 1):
        curr = float(input(f"Введите {i}-й элемент: "))
        if curr <= prev:
            is_increasing = False
        prev = curr
    print(True if is_increasing else False)
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите целое число N (> 1):  2
# Введите 1-й элемент:  3
# Введите 2-й элемент:  5
# True

# %% [markdown]
# Series22

# %%
try:
    N = int(input("Введите целое число N (> 1): "))
    prev = float(input("Введите 1-й элемент: "))
    violating_idx = 0
    for i in range(2, N + 1):
        curr = float(input(f"Введите {i}-й элемент: "))
        if curr >= prev and violating_idx == 0:
            violating_idx = i
        prev = curr
    print(violating_idx)
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите целое число N (> 1):  2
# Введите 1-й элемент:  5
# Введите 2-й элемент:  10
# 2

# %% [markdown]
# Series23

# %%
try:
    N = int(input("Введите целое число N (> 2): "))
    arr = []
    for i in range(N):
        arr.append(float(input(f"Введите {i + 1}-й элемент: ")))
    
    result = 0
    for i in range(1, N - 1):
        is_tooth = (arr[i] > arr[i - 1] and arr[i] > arr[i + 1]) or (arr[i] < arr[i - 1] and arr[i] < arr[i + 1])
        if not is_tooth:
            result = i + 1
            break
    print(result)
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите целое число N (> 2):  3
# Введите 1-й элемент:  2
# Введите 2-й элемент:  5
# Введите 3-й элемент:  1
# 0

# %% [markdown]
# Series24

# %%
try:
    N = int(input("Введите целое число N: "))
    arr = []
    for i in range(N):
        arr.append(int(input(f"Введите {i + 1}-й элемент: ")))
    
    zero_indices = [i for i, x in enumerate(arr) if x == 0]
    idx1 = zero_indices[-2]
    idx2 = zero_indices[-1]
    
    suma = sum(arr[idx1 + 1:idx2])
    print(f"Сумма между последними двумя нулями: {suma}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите целое число N:  2
# Введите 1-й элемент:  100
# Введите 2-й элемент:  200
# ОШИБКА!: list index out of range

# %% [markdown]
# Series25

# %%
try:
    N = int(input("Введите целое число N: "))
    arr = []
    for i in range(N):
        arr.append(int(input(f"Введите {i + 1}-й элемент: ")))
    
    zero_indices = [i for i, x in enumerate(arr) if x == 0]
    idx_first = zero_indices[0]
    idx_last = zero_indices[-1]
    
    suma = sum(arr[idx_first + 1:idx_last])
    print(f"Сумма между первым и последним нулями: {suma}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите целое число N:  2
# Введите 1-й элемент:  00
# Введите 2-й элемент:  00
# Сумма между первым и последним нулями: 0

# %% [markdown]
# Series26

# %%
try:
    K = int(input("Введите показатель степени K: "))
    N = int(input("Введите целое число N: "))
    for i in range(N):
        a = float(input("Введите вещественное число: "))
        print(f"{a}^{K} = {a ** K}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите показатель степени K:  3
# Введите целое число N:  2
# Введите вещественное число:  2.5
# 2.5^3 = 15.625
# Введите вещественное число:  5
# 5.0^3 = 125.0

# %% [markdown]
# Series27

# %%
try:
    N = int(input("Введите целое число N: "))
    for i in range(1, N + 1):
        a = float(input(f"Введите {i}-е вещественное число: "))
        print(f"{a}^{i} = {a ** i}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите целое число N:  2
# Введите 1-е вещественное число:  1
# 1.0^1 = 1.0
# Введите 2-е вещественное число:  1.5
# 1.5^2 = 2.25

# %% [markdown]
# Series28

# %%
try:
    N = int(input("Введите целое число N: "))
    for i in range(N):
        a = float(input(f"Введите {i + 1}-е вещественное число: "))
        power = N - i
        print(f"{a}^{power} = {a ** power}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите целое число N:  2
# Введите 1-е вещественное число:  1.5
# 1.5^2 = 2.25
# Введите 2-е вещественное число:  3.25
# 3.25^1 = 3.25

# %% [markdown]
# Series29

# %%
try:
    K = int(input("Введите количество наборов K: "))
    N = int(input("Введите количество элементов в наборе N: "))
    total_sum = 0
    for i in range(K):
        for j in range(N):
            a = int(input(f"Набор {i + 1}, элемент {j + 1}: "))
            total_sum += a
    print(f"Общая сумма всех элементов: {total_sum}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите количество наборов K:  2
# Введите количество элементов в наборе N:  1
# Набор 1, элемент 1:  1
# Набор 2, элемент 1:  3
# Общая сумма всех элементов: 4

# %% [markdown]
# Series30

# %%
try:
    K = int(input("Введите количество наборов K: "))
    N = int(input("Введите количество элементов в наборе N: "))
    for i in range(K):
        set_sum = 0
        for j in range(N):
            a = int(input(f"Набор {i + 1}, элемент {j + 1}: "))
            set_sum += a
        print(f"Сумма элементов набора {i + 1}: {set_sum}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите количество наборов K:  3
# Введите количество элементов в наборе N:  1
# Набор 1, элемент 1:  2
# Сумма элементов набора 1: 2
# Набор 2, элемент 1:  6
# Сумма элементов набора 2: 6
# Набор 3, элемент 1:  2
# Сумма элементов набора 3: 2

# %% [markdown]
# Series31

# %%
try:
    K = int(input("Введите количество наборов K: "))
    N = int(input("Введите количество элементов в наборе N: "))
    count_sets = 0
    for i in range(K):
        has_two = False
        for j in range(N):
            a = int(input(f"Набор {i + 1}, элемент {j + 1}: "))
            if a == 2:
                has_two = True
        if has_two:
            count_sets += 1
    print(f"Количество наборов, содержащих двойку: {count_sets}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите количество наборов K:  2
# Введите количество элементов в наборе N:  3
# Набор 1, элемент 1:  2
# Набор 1, элемент 2:  12
# Набор 1, элемент 3:  24
# Набор 2, элемент 1:  30
# Набор 2, элемент 2:  25
# Набор 2, элемент 3:  10
# Количество наборов, содержащих двойку: 1

# %% [markdown]
# Series32

# %%
try:
    K = int(input("Введите количество наборов K: "))
    N = int(input("Введите количество элементов в наборе N: "))
    for i in range(K):
        first_idx = 0
        for j in range(1, N + 1):
            a = int(input(f"Набор {i + 1}, элемент {j}: "))
            if a == 2 and first_idx == 0:
                first_idx = j
        print(f"Номер первой двойки в наборе {i + 1}: {first_idx}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите количество наборов K:  2
# Введите количество элементов в наборе N:  2
# Набор 1, элемент 1:  23
# Набор 1, элемент 2:  12
# Номер первой двойки в наборе 1: 0
# Набор 2, элемент 1:  53
# Набор 2, элемент 2:  52
# Номер первой двойки в наборе 2: 0

# %% [markdown]
# Series33

# %%
try:
    K = int(input("Введите количество наборов K: "))
    N = int(input("Введите количество элементов в наборе N: "))
    for i in range(K):
        last_idx = 0
        for j in range(1, N + 1):
            a = int(input(f"Набор {i + 1}, элемент {j}: "))
            if a == 2:
                last_idx = j
        print(f"Номер последней двойки в наборе {i + 1}: {last_idx}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите количество наборов K:  2
# Введите количество элементов в наборе N:  2
# Набор 1, элемент 1:  1
# Набор 1, элемент 2:  4
# Номер последней двойки в наборе 1: 0
# Набор 2, элемент 1:  2
# Набор 2, элемент 2:  5
# Номер последней двойки в наборе 2: 1

# %% [markdown]
# Series34

# %%
try:
    K = int(input("Введите количество наборов K: "))
    N = int(input("Введите количество элементов в наборе N: "))
    for i in range(K):
        has_two = False
        set_sum = 0
        for j in range(N):
            a = int(input(f"Набор {i + 1}, элемент {j + 1}: "))
            set_sum += a
            if a == 2:
                has_two = True
        if has_two:
            print(f"Сумма набора {i + 1}: {set_sum}")
        else:
            print(f"Результат набора {i + 1}: 0")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите количество наборов K:  2
# Введите количество элементов в наборе N:  2
# Набор 1, элемент 1:  23
# Набор 1, элемент 2:  32
# Результат набора 1: 0
# Набор 2, элемент 1:  24
# Набор 2, элемент 2:  15
# Результат набора 2: 0

# %% [markdown]
# Series35

# %%
try:
    K = int(input("Введите количество наборов K: "))
    total_count = 0
    for i in range(K):
        count = 0
        print(f"--- Ввод набора {i + 1} (до 0) ---")
        while True:
            a = int(input("Введите целое число: "))
            if a == 0:
                break
            count += 1
        print(f"Количество элементов в наборе {i + 1}: {count}")
        total_count += count
    print(f"Общее количество элементов во всех наборах: {total_count}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите количество наборов K:  2
# --- Ввод набора 1 (до 0) ---
# Введите целое число:  1
# Введите целое число:  4
# Введите целое число:  6
# Введите целое число:  0
# Количество элементов в наборе 1: 3
# --- Ввод набора 2 (до 0) ---
# Введите целое число:  122
# Введите целое число:  3
# Введите целое число:  41
# Введите целое число:  0
# Количество элементов в наборе 2: 3
# Общее количество элементов во всех наборах: 6

# %% [markdown]
# Series36

# %%
try:
    K = int(input("Введите количество наборов K: "))
    increasing_count = 0
    for i in range(K):
        print(f"--- Ввод набора {i + 1} (до 0) ---")
        prev = int(input("Введите число: "))
        is_increasing = True
        while True:
            curr = int(input("Введите число: "))
            if curr == 0:
                break
            if curr <= prev:
                is_increasing = False
            prev = curr
        if is_increasing:
            increasing_count += 1
    print(f"Количество возрастающих наборов: {increasing_count}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите количество наборов K:  2
# --- Ввод набора 1 (до 0) ---
# Введите число:  1
# Введите число:
# ОШИБКА!: invalid literal for int() with base 10: ''

# %% [markdown]
# Series37

# %%
try:
    K = int(input("Введите количество наборов K: "))
    monotonic_count = 0
    for i in range(K):
        print(f"--- Ввод набора {i + 1} (до 0) ---")
        prev = int(input("Введите число: "))
        is_inc = True
        is_dec = True
        while True:
            curr = int(input("Введите число: "))
            if curr == 0:
                break
            if curr <= prev:
                is_inc = False
            if curr >= prev:
                is_dec = False
            prev = curr
        if is_inc or is_dec:
            monotonic_count += 1
    print(f"Количество возрастающих или убывающих наборов: {monotonic_count}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите количество наборов K:  2
# --- Ввод набора 1 (до 0) ---
# Введите число:  30
# Введите число:  120
# Введите число:  345
# Введите число:  0
# --- Ввод набора 2 (до 0) ---
# Введите число:  21
# Введите число:  3
# Введите число:  5
# Введите число:  0
# Количество возрастающих или убывающих наборов: 1

# %% [markdown]
# Series38

# %%
try:
    K = int(input("Введите количество наборов K: "))
    for i in range(K):
        print(f"--- Ввод набора {i + 1} (до 0) ---")
        prev = int(input("Введите число: "))
        is_inc = True
        is_dec = True
        while True:
            curr = int(input("Введите число: "))
            if curr == 0:
                break
            if curr <= prev:
                is_inc = False
            if curr >= prev:
                is_dec = False
            prev = curr
        
        if is_inc:
            print(1)
        elif is_dec:
            print(-1)
        else:
            print(0)
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите количество наборов K:  2
# --- Ввод набора 1 (до 0) ---
# Введите число:  12
# Введите число:  3
# Введите число:  40
# Введите число:  0
# 0
# --- Ввод набора 2 (до 0) ---
# Введите число:  50
# Введите число:  12
# Введите число:  200
# Введите число:  400
# Введите число:  0
# 0

# %% [markdown]
# Series39

# %%
try:
    K = int(input("Введите количество наборов K: "))
    sawtooth_count = 0
    for i in range(K):
        print(f"--- Ввод набора {i + 1} (до 0) ---")
        arr = []
        while True:
            a = int(input("Введите число: "))
            if a == 0:
                break
            arr.append(a)
        
        is_sawtooth = True
        for j in range(1, len(arr) - 1):
            if not ((arr[j] > arr[j - 1] and arr[j] > arr[j + 1]) or (arr[j] < arr[j - 1] and arr[j] < arr[j + 1])):
                is_sawtooth = False
                break
        
        if is_sawtooth:
            sawtooth_count += 1
    print(f"Количество пилообразных наборов: {sawtooth_count}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите количество наборов K:  2
# --- Ввод набора 1 (до 0) ---
# Введите число:  1
# Введите число:  3
# Введите число:  4
# Введите число:  5
# Введите число:  50
# Введите число:  0
# --- Ввод набора 2 (до 0) ---
# Введите число:  212
# Введите число:  24240
# Введите число:  2410
# Введите число:  2450
# Введите число:  0
# Количество пилообразных наборов: 1

# %% [markdown]
# Series40

# %%
try:
    K = int(input("Введите количество наборов K: "))
    for i in range(K):
        print(f"--- Ввод набора {i + 1} (до 0) ---")
        arr = []
        while True:
            a = int(input("Введите число: "))
            if a == 0:
                break
            arr.append(a)
        
        violating_idx = 0
        for j in range(1, len(arr) - 1):
            if not ((arr[j] > arr[j - 1] and arr[j] > arr[j + 1]) or (arr[j] < arr[j - 1] and arr[j] < arr[j + 1])):
                violating_idx = j + 1
                break
        
        if violating_idx == 0:
            print(f"Пилообразный, количество элементов: {len(arr)}")
        else:
            print(f"Не зубец, номер элемента: {violating_idx}")
except Exception as e:
    print(f"ОШИБКА!: {e}")
# Out:
# Введите количество наборов K:  2
# --- Ввод набора 1 (до 0) ---
# Введите число:  31540
# Введите число:  4021345
# Введите число:  241210
# Введите число:  0
# Пилообразный, количество элементов: 3
# --- Ввод набора 2 (до 0) ---
# Введите число:  12
# Введите число:  124э
# ОШИБКА!: invalid literal for int() with base 10: '124э'
